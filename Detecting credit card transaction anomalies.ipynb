# %% [markdown]
# # Detecting anomalies in credit card transactions
#
# In this project, we will attempt to find anomalies in credit card transactions. This could help point out unusual behaviour by credit card customers which could be a result of fraud. In one csv, we have the data for the credit card numbers, the place where they were issued, and their respective credit limits. In another csv, we have the data for the credit card numbers, the date and time of the transaction, transaction amount, and the location of the transaction given by the latitudes and longitudes.
#
# I took the following steps:
# 1. Adding the credit limit information to the dataframe with transaction amount information
# 2. Calculating the percentage of credit limit consumed in a particular transaction
# 3. Deriving the latitudes and longitudes of places where the credit cards were issued and adding this information to the transactions dataframe
# 4. Calculating the distance between place of transaction and place of registration
# 5. Normalising the data and building a model having a sigmoid layer at the end
# 6. Fitting the model and making predictions

# %% [markdown]
# ## Preliminary steps

# %%
#Import all packages required for this project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from geopy.geocoders import Nominatim
import pgeocode
from geopy.extra.rate_limiter import RateLimiter
import geopy.distance
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import Normalizer, MinMaxScaler
from sklearn.pipeline import Pipeline
# Out:
# WARNING:tensorflow:From C:\Users\Digant\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load source CSVs to dataframes
cc_details_df = pd.read_csv('cc_info.csv')
transaction_details_df = pd.read_csv('transactions.csv')

# %%
cc_details_df.head()
# Out:
#         credit_card      city state  zipcode  credit_card_limit
# 0  1280981422329509    Dallas    PA    18612               6000
# 1  9737219864179988   Houston    PA    15342              16000
# 2  4749889059323202    Auburn    MA     1501              14000
# 3  9591503562024072   Orlando    WV    26412              18000
# 4  2095640259001271  New York    NY    10001              20000

# %%
transaction_details_df.head()
# Out:
#         credit_card                 date  transaction_dollar_amount  \
# 0  1003715054175576  2015-09-11 00:32:40                      43.78
# 1  1003715054175576  2015-10-24 22:23:08                     103.15
# 2  1003715054175576  2015-10-26 18:19:36                      48.55
# 3  1003715054175576  2015-10-22 19:41:10                     136.18
# 4  1003715054175576  2015-10-26 20:08:22                      71.82
#
#         Long        Lat
# 0 -80.174132  40.267370
# 1 -80.194240  40.180114
# 2 -80.211033  40.313004
# 3 -80.174138  40.290895
# 4 -80.238720  40.166719

# %%
transaction_details_df.dtypes
# Out:
# credit_card                    int64
# date                          object
# transaction_dollar_amount    float64
# Long                         float64
# Lat                          float64
# dtype: object

# %%
cc_details_df.dtypes
# Out:
# credit_card           int64
# city                 object
# state                object
# zipcode               int64
# credit_card_limit     int64
# dtype: object

# %%
transaction_details_df.shape
# Out:
# (294588, 5)

# %%
cc_details_df.shape
# Out:
# (984, 5)

# %%
# Creating a new dataframes to ensure source DFs are not affected by any transformations
trans_ = transaction_details_df
cc_ = cc_details_df

# %%
# Confirming that we have the data for credit cards that were used in the transactions
all_cards = cc_['credit_card']
trans_['credit_card'].isin(all_cards).unique()
# Out:
# array([ True])

# %% [markdown]
# ## 1. Adding the credit limit information to the dataframe with transaction amount information
#
# Here, we will first test a method to get the credit limit of a credit card used in a particular transaction. Then, we will use a for loop to repeat this process for all transactions. And finally, we will add this information to the trans_ dataframe.

# %%
# Output variable is a list
limit = []

# First we get the credit card number
credit_card_num_t = trans_['credit_card'].values[0]

# Now, we can match the credit card number with the credit card limit
for k in range(cc_.shape[0]):
    if credit_card_num_t == cc_['credit_card'].values[k]:
        limit_t = cc_['credit_card_limit'].values[k]
        limit.append(limit_t)

# %%
limit
# Out:
# [20000]

# %%
# Lets repeat this process for all transactions

# These are the credit card numbers for every transaction
trans_cred_values = trans_['credit_card'].values

# These are all the credit card numbers for which we have data
cc_values = cc_['credit_card'].values

#These are all the corresponding credit card limits
cc_limit_values = cc_['credit_card_limit'].values

limit_ = []
for j in range(trans_.shape[0]):
    # for every row in trans_
    # Take the credit card number
    credit_card_num_j = trans_cred_values[j]
    
    #Take the credit limit
    for k in range(cc_.shape[0]):
        if credit_card_num_j == cc_values[k]:
            limit_jk = cc_limit_values[k]
            limit_.append(limit_jk)

# %%
# Adding the credit limits to the trans_ dataframe
trans_['credit_limit'] = limit_

# %% [markdown]
# ## 2. Calculating the percentage of credit limit consumed in a particular transaction

# %%
trans_['perc_of_credit_limit'] = trans_['transaction_dollar_amount']/trans_['credit_limit']*100

# %%
trans_['perc_of_credit_limit'].describe()
# Out:
# count    294588.000000
# mean          0.660865
# std           1.310663
# min           0.000029
# 25%           0.233966
# 50%           0.411217
# 75%           0.670922
# max          49.660000
# Name: perc_of_credit_limit, dtype: float64

# %% [markdown]
# ## 3. Deriving the latitudes and longitudes of places where the credit cards were issued and adding this information to the transactions dataframe
#
# In this part, we will take the following steps:
# 1. Create a column in cc_ dataframe where will store the addresses
# 2. Extract all unique addresses into a new dataframe, 'ua_df'
# 3. Run a geocoder to get the latitudes and longitudes of all unique addresses
# 4. Add these coordinates to the cc_ dataframe just like we added credit limits from cc_ to trans_
# 5. Create a new dataframe, 'empty_coord_df', out of cc_ such it contains all credit cards that were assigned NaN coordinates
# 6. Run a geocoder to get the latitudes and longitudes of all zipcodes in the dataframe with NaN coordinates
# 7. Drop rows for which coordinates are still NaN values
# 8. Create a new dataframe, 'old_coord_df', out of cc_ that contains all credit cards that did not have NaN coordinates
# 9. Merge 'old_coord_df' and 'empty_coord_df' to create new_cc dataframe
# 10. Add the credit card coordinates from new_cc to trans_ just like we added credit limits from cc_ to trans_

# %%
# Since all the states are represented by their postal codes, we will need a dictionary to convert them all back to their names
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}
    
# invert the dictionary
abbrev_to_us_state = dict(map(reversed, us_state_to_abbrev.items()))

# %%
# Here we are creating a list for all addresses in cc_
# Lists of zipcodes, cities, and state postal codes
zips = cc_['zipcode'].values
cities = cc_['city'].values
state_code = cc_['state'].values

#List of addresses
city_state_ = []


for j in range(cc_.shape[0]):
    city_j = str(cities[j])
    # Converting postal state code to state name
    state_j = str(abbrev_to_us_state[state_code[j]])
    zips_j = str(zips[j])
    address_j = city_j + ', ' + state_j + ' - ' + zips_j +'.'
    city_state_.append(address_j)

# %%
# Adding the list we created to the cc_
cc_['Address'] = city_state_

# %%
# Creating the Nominatim object and setting a delay. You can choose to keep the delay at 1 second as well. The code will still function the same way
geolocator_08 = Nominatim(user_agent='Digi_98')
geocode = RateLimiter(geolocator_08.geocode, min_delay_seconds=2)

# %%
# Creating a dataframe with all unique addresses
unique_address = set(city_state_)

ua_df = pd.DataFrame(unique_address, columns=['Address'])

# %%
# Getting the location objects for all unique address that will contain coordinates and various other identifiers
ua_df['location'] = ua_df['Address'].apply(geolocator_08.geocode)

# %%
# Getting the latitudes and longitudes
ua_df['latitude'] = ua_df['location'].apply(lambda x: x.latitude if x != None else None)
ua_df['longitude'] = ua_df['location'].apply(lambda x: x.longitude if x != None else None)

# %%
ua_df
# Out:
#                               Address  \
# 0      Jackson, New Hampshire - 3846.
# 1        Seattle, Washington - 98060.
# 2    Knoxville, Pennsylvania - 16928.
# 3         New York, New York - 10001.
# 4      Indianapolis, Indiana - 46201.
# ..                                ...
# 119         Charleston, Maine - 4422.
# 120     Lafayette, New Jersey - 7848.
# 121        Chicago, Illinois - 60290.
# 122       Greensboro, Vermont - 5841.
# 123          Tulsa, Oklahoma - 74101.
#
#                                               location   latitude  longitude
# 0    (Jackson, Carroll County, New Hampshire, 03846...  44.144276 -71.181107
# 1                                                 None        NaN        NaN
# 2    (Knoxville, Tioga County, Pennsylvania, 16928,...  41.957293 -77.438872
# 3    (City of New York, New York, United States, (4...  40.712728 -74.006015
# 4    (Indianapolis, Marion County, Indiana, United ...  39.768333 -86.158350
# ..                                                 ...        ...        ...
# 119  (Charleston, Penobscot County, Maine, 04422, U...  45.085062 -69.040595
# 120                                               None        NaN        NaN
# 121  (Chicago, Cook County, Illinois, United States...  41.875562 -87.624421
# 122  (5841, Vermont Route 16, Wheelock, Caledonia C...  44.611439 -72.207900
# 123  (Tulsa Avenue, Arkoma, Le Flore County, Oklaho...  35.350777 -94.438694
#
# [124 rows x 4 columns]

# %%
# Adding all coordinates to cc_

# These are the addresses for every credit card
cc_address_values = cc_['Address'].values

# These are all the unique addresses for which we have data
ua_adress_values = ua_df['Address'].values

#These are all the corresponding latitudes
ua_lat_values = ua_df['latitude'].values

#These are all the corresponding longitudes
ua_lon_values = ua_df['longitude'].values

lat_ = []
lon_ = []

for j in range(cc_.shape[0]):
    # for every row in cc_
    # Take the address
    address_j = cc_address_values[j]
    
    #Take the latitude and longitude
    for k in range(ua_df.shape[0]):
        if address_j == ua_adress_values[k]:
            lat_jk = ua_lat_values[k]
            lon_jk = ua_lon_values[k]
            lat_.append(lat_jk)
            lon_.append(lon_jk)

# %%
lat_
# Out:
# [41.33617,
#  40.2464593,
#  42.1945465,
#  38.8712074,
#  40.7127281,
#  42.5542347,
#  40.4416941,
#  nan,
#  43.1763512,
#  34.0536909,
#  43.2309198,
#  40.2464593,
#  43.1763512,
#  nan,
#  43.1763512,
#  43.1763512,
#  nan,
#  43.1763512,
#  nan,
#  40.2464593,
#  41.5394353,
#  43.1763512,
#  43.1763512,
#  40.7392018,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  27.7635302,
#  42.3723379,
#  40.6345309,
#  42.4153739,
#  43.240451,
#  42.4153739,
#  nan,
#  27.7639145,
#  42.118675,
#  43.1763512,
#  43.1763512,
#  40.7392018,
#  41.8755616,
#  nan,
#  40.2464593,
#  34.0536909,
#  43.1763512,
#  41.33617,
#  43.1763512,
#  43.1763512,
#  40.2464593,
#  40.4416941,
#  44.79020125863546,
#  40.2464593,
#  40.4416941,
#  43.1763512,
#  39.100105,
#  43.1763512,
#  42.2125871,
#  35.4729886,
#  43.1763512,
#  43.1763512,
#  35.5939325,
#  37.7567819,
#  39.1361859,
#  43.1763512,
#  43.0828444,
#  43.1763512,
#  43.1763512,
#  42.3723379,
#  nan,
#  38.1523268,
#  43.0828444,
#  40.4416941,
#  43.1763512,
#  nan,
#  42.4153739,
#  43.1763512,
#  40.7127281,
#  42.8867166,
#  43.1763512,
#  43.1763512,
#  40.5885508,
#  40.2464593,
#  40.2464593,
#  42.118675,
#  40.2464593,
#  nan,
#  43.1763512,
#  40.7127281,
#  40.7392018,
#  38.1523268,
#  nan,
#  43.1763512,
#  43.1763512,
#  42.118675,
#  40.7392018,
#  38.1523268,
#  41.8755616,
#  34.0536909,
#  41.33617,
#  18.3013611,
#  43.1763512,
#  40.7127281,
#  39.7683331,
#  nan,
#  43.1763512,
#  41.8755616,
#  43.0208924,
#  40.2464593,
#  43.1763512,
#  29.9759983,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  40.7392018,
#  42.3723379,
#  40.2464593,
#  40.7127281,
#  43.1763512,
#  43.1763512,
#  41.33617,
#  43.1763512,
#  40.2464593,
#  43.1763512,
#  40.6345309,
#  43.1763512,
#  43.240451,
#  42.118675,
#  43.4083637,
#  43.1763512,
#  40.7596198,
#  43.1763512,
#  40.3325692,
#  nan,
#  40.6345309,
#  43.0828444,
#  41.6315276,
#  43.1763512,
#  40.3325692,
#  43.1763512,
#  43.1763512,
#  nan,
#  43.4083637,
#  40.7127281,
#  42.2459311,
#  43.1763512,
#  42.5542347,
#  40.7127281,
#  40.7392018,
#  40.7127281,
#  40.305598,
#  43.1763512,
#  43.1763512,
#  40.2464593,
#  nan,
#  41.9573206,
#  nan,
#  43.1763512,
#  27.7639145,
#  43.1763512,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  42.3723379,
#  43.1763512,
#  42.5542347,
#  40.2464593,
#  36.9528412,
#  40.7127281,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  42.4212463,
#  13.8657863,
#  43.1763512,
#  45.0850615,
#  42.118675,
#  40.7392018,
#  41.33617,
#  40.2464593,
#  41.33617,
#  43.1763512,
#  40.7127281,
#  40.7392018,
#  40.2464593,
#  nan,
#  40.6345309,
#  41.33617,
#  43.1763512,
#  40.7392018,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  30.6913462,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  38.1523268,
#  39.100105,
#  40.6345309,
#  43.1763512,
#  44.79020125863546,
#  43.1763512,
#  44.3105141,
#  43.1763512,
#  42.118675,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  44.154622,
#  43.1763512,
#  40.2464593,
#  40.2464593,
#  43.1763512,
#  40.2464593,
#  41.33617,
#  43.1763512,
#  nan,
#  43.0208924,
#  43.8993653,
#  40.4416941,
#  41.4899827,
#  40.7392018,
#  44.79020125863546,
#  43.8993653,
#  41.33617,
#  nan,
#  43.1763512,
#  43.1763512,
#  40.2464593,
#  43.1763512,
#  39.100105,
#  40.7392018,
#  43.1763512,
#  43.1763512,
#  42.118675,
#  18.3013611,
#  45.0850615,
#  35.4729886,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  34.0536909,
#  43.1763512,
#  41.6315276,
#  nan,
#  43.1763512,
#  40.7392018,
#  43.1763512,
#  30.421309,
#  43.1763512,
#  41.8755616,
#  35.4729886,
#  40.2464593,
#  41.5394353,
#  43.1763512,
#  43.8993653,
#  43.1763512,
#  41.33617,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  40.7392018,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.2309198,
#  41.33617,
#  43.1763512,
#  40.2464593,
#  40.2464593,
#  38.1523268,
#  nan,
#  43.1763512,
#  43.8993653,
#  43.1763512,
#  40.2464593,
#  40.4416941,
#  nan,
#  40.7392018,
#  42.75707266722072,
#  40.7127281,
#  44.611439210145754,
#  43.1763512,
#  43.1763512,
#  42.2125871,
#  43.1763512,
#  43.1763512,
#  32.5135356,
#  40.3325692,
#  43.1763512,
#  35.5939325,
#  43.8993653,
#  43.1763512,
#  42.5542347,
#  40.6345309,
#  43.1763512,
#  38.1523268,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  40.7392018,
#  36.9053822,
#  40.7127281,
#  40.7127281,
#  38.1523268,
#  43.1763512,
#  43.1763512,
#  nan,
#  nan,
#  40.7392018,
#  40.7127281,
#  40.2464593,
#  44.144276,
#  40.7127281,
#  43.1763512,
#  44.3105141,
#  40.7127281,
#  40.7127281,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  41.33617,
#  43.1763512,
#  42.447965138845255,
#  40.6345309,
#  40.2464593,
#  35.5939325,
#  41.33617,
#  43.1763512,
#  43.1763512,
#  34.0536909,
#  43.1763512,
#  34.0536909,
#  41.7317701,
#  43.1763512,
#  43.1763512,
#  44.144276,
#  35.5939325,
#  42.4153739,
#  43.1763512,
#  36.0993683,
#  43.1763512,
#  30.6913462,
#  43.1763512,
#  43.1763512,
#  44.3105141,
#  41.6315276,
#  41.33617,
#  41.7020432,
#  41.33617,
#  40.2464593,
#  40.7127281,
#  40.7127281,
#  41.7020432,
#  35.4729886,
#  44.144276,
#  43.1763512,
#  38.8712074,
#  35.4729886,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  39.100105,
#  43.1763512,
#  33.0015407,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  40.2464593,
#  nan,
#  40.7392018,
#  nan,
#  43.1763512,
#  40.2464593,
#  41.33617,
#  40.7392018,
#  43.1763512,
#  43.1763512,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  42.118675,
#  33.0015407,
#  40.2464593,
#  35.4729886,
#  35.4729886,
#  40.7392018,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  41.8755616,
#  43.1763512,
#  43.1763512,
#  42.3554334,
#  nan,
#  43.1763512,
#  43.0208924,
#  43.1763512,
#  41.6315276,
#  43.1763512,
#  40.2464593,
#  41.33617,
#  44.3105141,
#  42.118675,
#  nan,
#  45.0850615,
#  40.7127281,
#  39.100105,
#  42.447965138845255,
#  44.094283,
#  44.3105141,
#  37.6922361,
#  43.1763512,
#  42.118675,
#  43.1763512,
#  41.7317701,
#  43.1763512,
#  43.1763512,
#  44.79020125863546,
#  40.6345309,
#  43.1763512,
#  41.6770463,
#  43.1149568,
#  43.1763512,
#  41.7317701,
#  44.3105141,
#  43.1763512,
#  43.1763512,
#  41.6315276,
#  44.3105141,
#  40.2464593,
#  40.7392018,
#  nan,
#  41.33617,
#  43.1763512,
#  40.2464593,
#  42.1945465,
#  40.7127281,
#  43.1763512,
#  nan,
#  42.8867166,
#  43.1763512,
#  43.1763512,
#  nan,
#  43.710614519342656,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.983922,
#  43.1763512,
#  43.1763512,
#  32.1462643,
#  40.7392018,
#  41.7020432,
#  43.1763512,
#  43.1763512,
#  33.0015407,
#  43.1763512,
#  43.1763512,
#  41.33617,
#  43.1763512,
#  40.6345309,
#  42.3723379,
#  38.1523268,
#  44.154622,
#  40.2464593,
#  40.7127281,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  40.2464593,
#  44.154622,
#  43.1763512,
#  43.8993653,
#  43.1763512,
#  43.1763512,
#  40.2464593,
#  18.3013611,
#  37.7567819,
#  27.9477595,
#  43.1763512,
#  40.6345309,
#  40.7127281,
#  43.1763512,
#  40.2464593,
#  40.7392018,
#  43.1763512,
#  43.1763512,
#  40.7392018,
#  43.1763512,
#  44.154622,
#  44.154622,
#  40.7127281,
#  43.1763512,
#  42.8867166,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  40.7392018,
#  38.1523268,
#  27.7639145,
#  38.1523268,
#  18.3013611,
#  40.7127281,
#  43.1763512,
#  43.1763512,
#  40.7127281,
#  43.1763512,
#  41.4086874,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  39.100105,
#  42.118675,
#  40.2464593,
#  43.1763512,
#  40.7127281,
#  35.3507765,
#  40.2464593,
#  40.2464593,
#  43.1763512,
#  41.9758872,
#  33.0015407,
#  41.33617,
#  40.6345309,
#  40.6345309,
#  43.710614519342656,
#  38.1523268,
#  43.1763512,
#  nan,
#  40.2464593,
#  43.1763512,
#  43.8993653,
#  43.1763512,
#  43.1763512,
#  nan,
#  38.1523268,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  44.144276,
#  39.100105,
#  42.8241725,
#  43.1763512,
#  38.1040864,
#  43.1763512,
#  41.7695463,
#  40.2464593,
#  42.2791281,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  39.7683331,
#  40.7127281,
#  27.7639145,
#  43.1763512,
#  43.0828444,
#  40.7127281,
#  44.79020125863546,
#  42.4212463,
#  43.1763512,
#  41.33617,
#  43.1763512,
#  40.2464593,
#  44.3105141,
#  40.7127281,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  43.8993653,
#  38.1523268,
#  43.1763512,
#  43.1763512,
#  40.6345309,
#  43.1763512,
#  43.1763512,
#  nan,
#  nan,
#  39.100105,
#  44.3105141,
#  43.1763512,
#  nan,
#  43.1763512,
#  43.1763512,
#  36.9053822,
#  43.1763512,
#  43.1763512,
#  40.7127281,
#  43.1763512,
#  43.1763512,
#  40.7127281,
#  40.2464593,
#  42.5542347,
#  42.3723379,
#  41.8755616,
#  40.4416941,
#  42.5542347,
#  43.1763512,
#  43.1763512,
#  29.9759983,
#  41.33617,
#  nan,
#  39.100105,
#  42.5542347,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  nan,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  nan,
#  42.118675,
#  40.2464593,
#  41.33617,
#  40.2464593,
#  43.1763512,
#  40.6345309,
#  43.1763512,
#  27.7639145,
#  41.33617,
#  34.729847,
#  nan,
#  40.2464593,
#  35.5939325,
#  43.2309198,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  40.7127281,
#  41.8755616,
#  42.4153739,
#  42.3723379,
#  43.710614519342656,
#  39.7109284,
#  40.7127281,
#  39.3281057,
#  nan,
#  44.144276,
#  43.1763512,
#  43.1763512,
#  nan,
#  40.7392018,
#  43.2309198,
#  33.0015407,
#  40.2464593,
#  43.1763512,
#  44.154622,
#  40.2464593,
#  40.2464593,
#  38.1523268,
#  nan,
#  43.1763512,
#  40.7127281,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  40.7392018,
#  38.8712074,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  nan,
#  40.7392018,
#  43.1763512,
#  41.9573206,
#  43.1763512,
#  43.1763512,
#  18.3013611,
#  40.7127281,
#  40.7127281,
#  43.1763512,
#  44.79020125863546,
#  41.6315276,
#  42.5542347,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  nan,
#  nan,
#  39.7683331,
#  43.1763512,
#  18.3013611,
#  43.1763512,
#  41.33617,
#  40.7127281,
#  41.33617,
#  43.1763512,
#  43.1763512,
#  36.868113,
#  43.1763512,
#  43.1763512,
#  39.2908816,
#  43.1763512,
#  43.1763512,
#  35.2072185,
#  42.3723379,
#  43.1763512,
#  41.33617,
#  44.3105141,
#  43.4083637,
#  43.1763512,
#  40.7392018,
#  42.118675,
#  43.1763512,
#  43.1763512,
#  40.6345309,
#  43.1763512,
#  33.0015407,
#  27.9477595,
#  39.7683331,
#  43.1763512,
#  40.7392018,
#  43.1763512,
#  46.3083815,
#  44.793044,
#  42.118675,
#  43.1763512,
#  nan,
#  41.33617,
#  43.1763512,
#  40.7392018,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.8993653,
#  43.1763512,
#  42.75707266722072,
#  43.1763512,
#  43.1763512,
#  40.7127281,
#  43.1763512,
#  43.1763512,
#  13.8657863,
#  34.0536909,
#  44.144276,
#  40.7392018,
#  43.1763512,
#  nan,
#  40.2464593,
#  40.2464593,
#  42.5542347,
#  43.1763512,
#  nan,
#  18.3013611,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  36.9053822,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  40.8466508,
#  43.1763512,
#  40.2464593,
#  41.9572933,
#  32.2228765,
#  43.1763512,
#  35.4729886,
#  40.7392018,
#  43.1763512,
#  40.7392018,
#  40.7127281,
#  39.100105,
#  43.1763512,
#  42.5542347,
#  43.1763512,
#  40.2464593,
#  43.1763512,
#  nan,
#  42.2125871,
#  43.1763512,
#  27.7639145,
#  43.1763512,
#  43.1763512,
#  42.3554334,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  43.6166163,
#  43.1763512,
#  40.7127281,
#  43.1763512,
#  41.33617,
#  43.1763512,
#  41.33617,
#  43.1763512,
#  nan,
#  43.1763512,
#  41.33617,
#  40.7127281,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  nan,
#  nan,
#  42.2125871,
#  41.33617,
#  42.3723379,
#  43.1763512,
#  43.1763512,
#  40.7127281,
#  43.1763512,
#  40.2464593,
#  42.577873,
#  33.0015407,
#  42.53870948879677,
#  42.3723379,
#  43.1763512,
#  35.5939325,
#  38.1523268,
#  nan,
#  43.1763512,
#  34.0536909,
#  43.1763512,
#  40.2464593,
#  43.1763512,
#  40.7596198,
#  40.2464593,
#  40.7392018,
#  40.2464593,
#  nan,
#  nan,
#  42.0187713,
#  41.33617,
#  43.1763512,
#  44.79020125863546,
#  43.1763512,
#  40.7127281,
#  43.1763512,
#  40.2464593,
#  43.1763512,
#  40.5834557,
#  nan,
#  43.1763512,
#  38.1523268,
#  43.1763512,
#  43.1763512,
#  41.8755616,
#  43.1763512,
#  39.100105,
#  40.7392018,
#  40.7392018,
#  43.1763512,
#  40.2464593,
#  42.5542347,
#  nan,
#  40.7392018,
#  17.9991775,
#  40.6345309,
#  44.144276,
#  nan,
#  36.9053822,
#  41.8755616,
#  43.1763512,
#  43.1763512,
#  41.6315276,
#  40.7127281,
#  40.2464593,
#  nan,
#  40.7127281,
#  43.1763512,
#  41.33617,
#  43.1763512,
#  40.7127281,
#  43.1763512,
#  41.8711524,
#  43.710614519342656,
#  43.1763512,
#  44.902578,
#  43.1763512,
#  43.6166163,
#  nan,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  nan,
#  39.100105,
#  43.1763512,
#  42.118675,
#  44.3105141,
#  27.7639145,
#  43.1763512,
#  38.1523268,
#  41.6315276,
#  40.7392018,
#  40.5564586,
#  43.1763512,
#  40.2464593,
#  33.0015407,
#  40.7127281,
#  40.7392018,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  nan,
#  38.8712074,
#  43.1763512,
#  41.6315276,
#  nan,
#  42.8867166,
#  43.1763512,
#  33.0015407,
#  43.1763512,
#  41.33617,
#  26.1223084,
#  44.79020125863546,
#  42.118675,
#  40.7127281,
#  43.0828444,
#  43.1763512,
#  43.1763512,
#  40.7392018,
#  42.118675,
#  40.7127281,
#  42.118675,
#  40.7392018,
#  35.4729886,
#  43.1763512,
#  43.1763512,
#  40.7127281,
#  43.1763512,
#  43.1763512,
#  43.1763512,
#  40.8272257,
#  nan,
#  43.1763512,
#  40.7127281,
#  43.1763512,
#  42.482690984665695,
#  43.1763512,
#  43.1763512,
#  30.7852708,
#  43.1763512,
#  40.7392018,
#  43.1763512,
#  43.1763512,
#  44.8542374,
#  18.3013611,
#  43.1763512,
#  40.7127281,
#  42.75707266722072,
#  40.2464593,
#  43.1763512,
#  43.8993653,
#  40.2464593,
#  40.2464593,
#  43.1763512,
#  41.6315276,
#  45.0850615,
#  43.1763512,
#  nan,
#  40.7127281,
#  43.1763512,
#  40.7392018,
#  40.2464593,
#  43.1763512,
#  43.1763512,
#  32.1462643,
#  40.2464593]

# %%
lon_
# Out:
# [-75.9632636,
#  -80.2114472,
#  -71.8358095,
#  -80.5937044,
#  -74.0060152,
#  -77.4724875,
#  -79.9900861,
#  nan,
#  -72.0969498,
#  -118.242766,
#  -76.3001887,
#  -80.2114472,
#  -72.0969498,
#  nan,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  -72.0969498,
#  nan,
#  -80.2114472,
#  -85.5394484,
#  -72.0969498,
#  -72.0969498,
#  -89.0164626,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -97.4033191,
#  -73.3678063,
#  -76.5888514,
#  -71.1564428,
#  -75.883942,
#  -71.1564428,
#  nan,
#  -98.2388953,
#  -72.546951,
#  -72.0969498,
#  -72.0969498,
#  -89.0164626,
#  -87.6244212,
#  nan,
#  -80.2114472,
#  -118.242766,
#  -72.0969498,
#  -75.9632636,
#  -72.0969498,
#  -72.0969498,
#  -80.2114472,
#  -79.9900861,
#  -72.2964057457816,
#  -80.2114472,
#  -79.9900861,
#  -72.0969498,
#  -94.5781416,
#  -72.0969498,
#  -74.5693201,
#  -97.5170536,
#  -72.0969498,
#  -72.0969498,
#  -105.223896,
#  -81.1742659,
#  -76.5490844,
#  -72.0969498,
#  -76.3771554,
#  -72.0969498,
#  -72.0969498,
#  -73.3678063,
#  nan,
#  -81.447892,
#  -76.3771554,
#  -79.9900861,
#  -72.0969498,
#  nan,
#  -71.1564428,
#  -72.0969498,
#  -74.0060152,
#  -78.8783922,
#  -72.0969498,
#  -72.0969498,
#  -73.6582631,
#  -80.2114472,
#  -80.2114472,
#  -72.546951,
#  -80.2114472,
#  nan,
#  -72.0969498,
#  -74.0060152,
#  -89.0164626,
#  -81.447892,
#  nan,
#  -72.0969498,
#  -72.0969498,
#  -72.546951,
#  -89.0164626,
#  -81.447892,
#  -87.6244212,
#  -118.242766,
#  -75.9632636,
#  -66.0371364,
#  -72.0969498,
#  -74.0060152,
#  -86.1583502,
#  nan,
#  -72.0969498,
#  -87.6244212,
#  -78.4953015,
#  -80.2114472,
#  -72.0969498,
#  -90.0782127,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -89.0164626,
#  -73.3678063,
#  -80.2114472,
#  -74.0060152,
#  -72.0969498,
#  -72.0969498,
#  -75.9632636,
#  -72.0969498,
#  -80.2114472,
#  -72.0969498,
#  -76.5888514,
#  -72.0969498,
#  -75.883942,
#  -72.546951,
#  -84.6066704,
#  -72.0969498,
#  -111.886797,
#  -72.0969498,
#  -81.7415163,
#  nan,
#  -76.5888514,
#  -76.3771554,
#  -78.0911354,
#  -72.0969498,
#  -81.7415163,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  -84.6066704,
#  -74.0060152,
#  -71.2828342,
#  -72.0969498,
#  -77.4724875,
#  -74.0060152,
#  -89.0164626,
#  -74.0060152,
#  -89.6028829,
#  -72.0969498,
#  -72.0969498,
#  -80.2114472,
#  nan,
#  -71.6478436,
#  nan,
#  -72.0969498,
#  -98.2388953,
#  -72.0969498,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -73.3678063,
#  -72.0969498,
#  -77.4724875,
#  -80.2114472,
#  -79.3602341,
#  -74.0060152,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -71.6874099,
#  -90.413289,
#  -72.0969498,
#  -69.0405949,
#  -72.546951,
#  -89.0164626,
#  -75.9632636,
#  -80.2114472,
#  -75.9632636,
#  -72.0969498,
#  -74.0060152,
#  -89.0164626,
#  -80.2114472,
#  nan,
#  -76.5888514,
#  -75.9632636,
#  -72.0969498,
#  -89.0164626,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -88.0437509,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -81.447892,
#  -94.5781416,
#  -76.5888514,
#  -72.0969498,
#  -72.2964057457816,
#  -72.0969498,
#  -73.2531419,
#  -72.0969498,
#  -72.546951,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -75.708847,
#  -72.0969498,
#  -80.2114472,
#  -80.2114472,
#  -72.0969498,
#  -80.2114472,
#  -75.9632636,
#  -72.0969498,
#  nan,
#  -78.4953015,
#  -71.148834,
#  -79.9900861,
#  -71.3137707,
#  -89.0164626,
#  -72.2964057457816,
#  -71.148834,
#  -75.9632636,
#  nan,
#  -72.0969498,
#  -72.0969498,
#  -80.2114472,
#  -72.0969498,
#  -94.5781416,
#  -89.0164626,
#  -72.0969498,
#  -72.0969498,
#  -72.546951,
#  -66.0371364,
#  -69.0405949,
#  -97.5170536,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -118.242766,
#  -72.0969498,
#  -78.0911354,
#  nan,
#  -72.0969498,
#  -89.0164626,
#  -72.0969498,
#  -87.2169149,
#  -72.0969498,
#  -87.6244212,
#  -97.5170536,
#  -80.2114472,
#  -85.5394484,
#  -72.0969498,
#  -71.148834,
#  -72.0969498,
#  -75.9632636,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -89.0164626,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -76.3001887,
#  -75.9632636,
#  -72.0969498,
#  -80.2114472,
#  -80.2114472,
#  -81.447892,
#  nan,
#  -72.0969498,
#  -71.148834,
#  -72.0969498,
#  -80.2114472,
#  -79.9900861,
#  nan,
#  -89.0164626,
#  -72.70572346023897,
#  -74.0060152,
#  -72.2079001899944,
#  -72.0969498,
#  -72.0969498,
#  -74.5693201,
#  -72.0969498,
#  -72.0969498,
#  -93.7477839,
#  -81.7415163,
#  -72.0969498,
#  -105.223896,
#  -71.148834,
#  -72.0969498,
#  -77.4724875,
#  -76.5888514,
#  -72.0969498,
#  -81.447892,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -89.0164626,
#  -82.3109761,
#  -74.0060152,
#  -74.0060152,
#  -81.447892,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  nan,
#  -89.0164626,
#  -74.0060152,
#  -80.2114472,
#  -71.181107,
#  -74.0060152,
#  -72.0969498,
#  -73.2531419,
#  -74.0060152,
#  -74.0060152,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -75.9632636,
#  -72.0969498,
#  -71.24273201583513,
#  -76.5888514,
#  -80.2114472,
#  -105.223896,
#  -75.9632636,
#  -72.0969498,
#  -72.0969498,
#  -118.242766,
#  -72.0969498,
#  -118.242766,
#  -70.8200371,
#  -72.0969498,
#  -72.0969498,
#  -71.181107,
#  -105.223896,
#  -71.1564428,
#  -72.0969498,
#  -81.9873491,
#  -72.0969498,
#  -88.0437509,
#  -72.0969498,
#  -72.0969498,
#  -73.2531419,
#  -78.0911354,
#  -75.9632636,
#  -72.3011917,
#  -75.9632636,
#  -80.2114472,
#  -74.0060152,
#  -74.0060152,
#  -72.3011917,
#  -97.5170536,
#  -71.181107,
#  -72.0969498,
#  -80.5937044,
#  -97.5170536,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -94.5781416,
#  -72.0969498,
#  -82.4112377,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -80.2114472,
#  nan,
#  -89.0164626,
#  nan,
#  -72.0969498,
#  -80.2114472,
#  -75.9632636,
#  -89.0164626,
#  -72.0969498,
#  -72.0969498,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.546951,
#  -82.4112377,
#  -80.2114472,
#  -97.5170536,
#  -97.5170536,
#  -89.0164626,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -87.6244212,
#  -72.0969498,
#  -72.0969498,
#  -71.060511,
#  nan,
#  -72.0969498,
#  -78.4953015,
#  -72.0969498,
#  -78.0911354,
#  -72.0969498,
#  -80.2114472,
#  -75.9632636,
#  -73.2531419,
#  -72.546951,
#  nan,
#  -69.0405949,
#  -74.0060152,
#  -94.5781416,
#  -71.24273201583513,
#  -73.231044,
#  -73.2531419,
#  -97.3375448,
#  -72.0969498,
#  -72.546951,
#  -72.0969498,
#  -70.8200371,
#  -72.0969498,
#  -72.0969498,
#  -72.2964057457816,
#  -76.5888514,
#  -72.0969498,
#  -71.2661597,
#  -71.8948666,
#  -72.0969498,
#  -70.8200371,
#  -73.2531419,
#  -72.0969498,
#  -72.0969498,
#  -78.0911354,
#  -73.2531419,
#  -80.2114472,
#  -89.0164626,
#  nan,
#  -75.9632636,
#  -72.0969498,
#  -80.2114472,
#  -71.8358095,
#  -74.0060152,
#  -72.0969498,
#  nan,
#  -78.8783922,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  -72.42214772743357,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -69.33403,
#  -72.0969498,
#  -72.0969498,
#  -85.0132629,
#  -89.0164626,
#  -72.3011917,
#  -72.0969498,
#  -72.0969498,
#  -82.4112377,
#  -72.0969498,
#  -72.0969498,
#  -75.9632636,
#  -72.0969498,
#  -76.5888514,
#  -73.3678063,
#  -81.447892,
#  -75.708847,
#  -80.2114472,
#  -74.0060152,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -80.2114472,
#  -75.708847,
#  -72.0969498,
#  -71.148834,
#  -72.0969498,
#  -72.0969498,
#  -80.2114472,
#  -66.0371364,
#  -81.1742659,
#  -82.458444,
#  -72.0969498,
#  -76.5888514,
#  -74.0060152,
#  -72.0969498,
#  -80.2114472,
#  -89.0164626,
#  -72.0969498,
#  -72.0969498,
#  -89.0164626,
#  -72.0969498,
#  -75.708847,
#  -75.708847,
#  -74.0060152,
#  -72.0969498,
#  -78.8783922,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -89.0164626,
#  -81.447892,
#  -98.2388953,
#  -81.447892,
#  -66.0371364,
#  -74.0060152,
#  -72.0969498,
#  -72.0969498,
#  -74.0060152,
#  -72.0969498,
#  -75.6621294,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -94.5781416,
#  -72.546951,
#  -80.2114472,
#  -72.0969498,
#  -74.0060152,
#  -94.438694,
#  -80.2114472,
#  -80.2114472,
#  -72.0969498,
#  -91.6704053,
#  -82.4112377,
#  -75.9632636,
#  -76.5888514,
#  -76.5888514,
#  -72.42214772743357,
#  -81.447892,
#  -72.0969498,
#  nan,
#  -80.2114472,
#  -72.0969498,
#  -71.148834,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  -81.447892,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -71.181107,
#  -94.5781416,
#  -72.18146,
#  -72.0969498,
#  -122.2566367,
#  -72.0969498,
#  -71.128656,
#  -80.2114472,
#  -72.9801282,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -86.1583502,
#  -74.0060152,
#  -98.2388953,
#  -72.0969498,
#  -76.3771554,
#  -74.0060152,
#  -72.2964057457816,
#  -71.6874099,
#  -72.0969498,
#  -75.9632636,
#  -72.0969498,
#  -80.2114472,
#  -73.2531419,
#  -74.0060152,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -71.148834,
#  -81.447892,
#  -72.0969498,
#  -72.0969498,
#  -76.5888514,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  nan,
#  -94.5781416,
#  -73.2531419,
#  -72.0969498,
#  nan,
#  -72.0969498,
#  -72.0969498,
#  -82.3109761,
#  -72.0969498,
#  -72.0969498,
#  -74.0060152,
#  -72.0969498,
#  -72.0969498,
#  -74.0060152,
#  -80.2114472,
#  -77.4724875,
#  -73.3678063,
#  -87.6244212,
#  -79.9900861,
#  -77.4724875,
#  -72.0969498,
#  -72.0969498,
#  -90.0782127,
#  -75.9632636,
#  nan,
#  -94.5781416,
#  -77.4724875,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  -72.546951,
#  -80.2114472,
#  -75.9632636,
#  -80.2114472,
#  -72.0969498,
#  -76.5888514,
#  -72.0969498,
#  -98.2388953,
#  -75.9632636,
#  -86.5859011,
#  nan,
#  -80.2114472,
#  -105.223896,
#  -76.3001887,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -74.0060152,
#  -87.6244212,
#  -71.1564428,
#  -73.3678063,
#  -72.42214772743357,
#  -77.4894339,
#  -74.0060152,
#  -85.5016372,
#  nan,
#  -71.181107,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  -89.0164626,
#  -76.3001887,
#  -82.4112377,
#  -80.2114472,
#  -72.0969498,
#  -75.708847,
#  -80.2114472,
#  -80.2114472,
#  -81.447892,
#  nan,
#  -72.0969498,
#  -74.0060152,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -89.0164626,
#  -80.5937044,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  -89.0164626,
#  -72.0969498,
#  -71.6478436,
#  -72.0969498,
#  -72.0969498,
#  -66.0371364,
#  -74.0060152,
#  -74.0060152,
#  -72.0969498,
#  -72.2964057457816,
#  -78.0911354,
#  -77.4724875,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  nan,
#  -86.1583502,
#  -72.0969498,
#  -66.0371364,
#  -72.0969498,
#  -75.9632636,
#  -74.0060152,
#  -75.9632636,
#  -72.0969498,
#  -72.0969498,
#  -93.2968516,
#  -72.0969498,
#  -72.0969498,
#  -76.610759,
#  -72.0969498,
#  -72.0969498,
#  -101.833824,
#  -73.3678063,
#  -72.0969498,
#  -75.9632636,
#  -73.2531419,
#  -84.6066704,
#  -72.0969498,
#  -89.0164626,
#  -72.546951,
#  -72.0969498,
#  -72.0969498,
#  -76.5888514,
#  -72.0969498,
#  -82.4112377,
#  -82.458444,
#  -86.1583502,
#  -72.0969498,
#  -89.0164626,
#  -72.0969498,
#  -67.842521,
#  -69.296951,
#  -72.546951,
#  -72.0969498,
#  nan,
#  -75.9632636,
#  -72.0969498,
#  -89.0164626,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -71.148834,
#  -72.0969498,
#  -72.70572346023897,
#  -72.0969498,
#  -72.0969498,
#  -74.0060152,
#  -72.0969498,
#  -72.0969498,
#  -90.413289,
#  -118.242766,
#  -71.181107,
#  -89.0164626,
#  -72.0969498,
#  nan,
#  -80.2114472,
#  -80.2114472,
#  -77.4724875,
#  -72.0969498,
#  nan,
#  -66.0371364,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -82.3109761,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -73.8785937,
#  -72.0969498,
#  -80.2114472,
#  -77.4388719,
#  -110.974847,
#  -72.0969498,
#  -97.5170536,
#  -89.0164626,
#  -72.0969498,
#  -89.0164626,
#  -74.0060152,
#  -94.5781416,
#  -72.0969498,
#  -77.4724875,
#  -72.0969498,
#  -80.2114472,
#  -72.0969498,
#  nan,
#  -74.5693201,
#  -72.0969498,
#  -98.2388953,
#  -72.0969498,
#  -72.0969498,
#  -71.060511,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -116.200886,
#  -72.0969498,
#  -74.0060152,
#  -72.0969498,
#  -75.9632636,
#  -72.0969498,
#  -75.9632636,
#  -72.0969498,
#  nan,
#  -72.0969498,
#  -75.9632636,
#  -74.0060152,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  nan,
#  -74.5693201,
#  -75.9632636,
#  -73.3678063,
#  -72.0969498,
#  -72.0969498,
#  -74.0060152,
#  -72.0969498,
#  -80.2114472,
#  -70.7689354,
#  -82.4112377,
#  -71.70861545575411,
#  -73.3678063,
#  -72.0969498,
#  -105.223896,
#  -81.447892,
#  nan,
#  -72.0969498,
#  -118.242766,
#  -72.0969498,
#  -80.2114472,
#  -72.0969498,
#  -111.886797,
#  -80.2114472,
#  -89.0164626,
#  -80.2114472,
#  nan,
#  nan,
#  -80.3460736,
#  -75.9632636,
#  -72.0969498,
#  -72.2964057457816,
#  -72.0969498,
#  -74.0060152,
#  -72.0969498,
#  -80.2114472,
#  -72.0969498,
#  -74.1496048,
#  nan,
#  -72.0969498,
#  -81.447892,
#  -72.0969498,
#  -72.0969498,
#  -87.6244212,
#  -72.0969498,
#  -94.5781416,
#  -89.0164626,
#  -89.0164626,
#  -72.0969498,
#  -80.2114472,
#  -77.4724875,
#  nan,
#  -89.0164626,
#  -77.035741,
#  -76.5888514,
#  -71.181107,
#  nan,
#  -82.3109761,
#  -87.6244212,
#  -72.0969498,
#  -72.0969498,
#  -78.0911354,
#  -74.0060152,
#  -80.2114472,
#  nan,
#  -74.0060152,
#  -72.0969498,
#  -75.9632636,
#  -72.0969498,
#  -74.0060152,
#  -72.0969498,
#  -71.5520471,
#  -72.42214772743357,
#  -72.0969498,
#  -72.638855,
#  -72.0969498,
#  -116.200886,
#  nan,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  -94.5781416,
#  -72.0969498,
#  -72.546951,
#  -73.2531419,
#  -98.2388953,
#  -72.0969498,
#  -81.447892,
#  -78.0911354,
#  -89.0164626,
#  -78.0977847,
#  -72.0969498,
#  -80.2114472,
#  -82.4112377,
#  -74.0060152,
#  -89.0164626,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  nan,
#  -80.5937044,
#  -72.0969498,
#  -78.0911354,
#  nan,
#  -78.8783922,
#  -72.0969498,
#  -82.4112377,
#  -72.0969498,
#  -75.9632636,
#  -80.1433786,
#  -72.2964057457816,
#  -72.546951,
#  -74.0060152,
#  -76.3771554,
#  -72.0969498,
#  -72.0969498,
#  -89.0164626,
#  -72.546951,
#  -74.0060152,
#  -72.546951,
#  -89.0164626,
#  -97.5170536,
#  -72.0969498,
#  -72.0969498,
#  -74.0060152,
#  -72.0969498,
#  -72.0969498,
#  -72.0969498,
#  -93.6072329,
#  nan,
#  -72.0969498,
#  -74.0060152,
#  -72.0969498,
#  -72.76014766740703,
#  -72.0969498,
#  -72.0969498,
#  -83.5596907,
#  -72.0969498,
#  -89.0164626,
#  -72.0969498,
#  -72.0969498,
#  -68.3280757,
#  -66.0371364,
#  -72.0969498,
#  -74.0060152,
#  -72.70572346023897,
#  -80.2114472,
#  -72.0969498,
#  -71.148834,
#  -80.2114472,
#  -80.2114472,
#  -72.0969498,
#  -78.0911354,
#  -69.0405949,
#  -72.0969498,
#  nan,
#  -74.0060152,
#  -72.0969498,
#  -89.0164626,
#  -80.2114472,
#  -72.0969498,
#  -72.0969498,
#  -85.0132629,
#  -80.2114472]

# %%
cc_['latitude'] = lat_
cc_['longitude'] = lon_

# %%
cc_.head()
# Out:
#         credit_card      city state  zipcode  credit_card_limit  \
# 0  1280981422329509    Dallas    PA    18612               6000
# 1  9737219864179988   Houston    PA    15342              16000
# 2  4749889059323202    Auburn    MA     1501              14000
# 3  9591503562024072   Orlando    WV    26412              18000
# 4  2095640259001271  New York    NY    10001              20000
#
#                            Address   latitude  longitude
# 0    Dallas, Pennsylvania - 18612.  41.336170 -75.963264
# 1   Houston, Pennsylvania - 15342.  40.246459 -80.211447
# 2    Auburn, Massachusetts - 1501.  42.194547 -71.835809
# 3  Orlando, West Virginia - 26412.  38.871207 -80.593704
# 4      New York, New York - 10001.  40.712728 -74.006015

# %%
# Creating a dataframe that contains only empty coordinate credit cards

empty_coord_df = cc_[cc_['longitude'].isna()]

no_lon_cc = empty_coord_df['credit_card'].values

# %%
empty_coord_df.head()
# Out:
#          credit_card              city state  zipcode  credit_card_limit  \
# 7   7482288151831611        Birmingham    NJ     8011               4000
# 13  8536914250563809  Colorado Springs    CO    80509              14000
# 16  2216132730528773     San Francisco    CA    94101              18000
# 18  9548629685194612          Columbus    NJ     8022               7000
# 35  2925559987432581            Tacoma    WA    98401              10000
#
#                                 Address  latitude  longitude
# 7        Birmingham, New Jersey - 8011.       NaN        NaN
# 13  Colorado Springs, Colorado - 80509.       NaN        NaN
# 16   San Francisco, California - 94101.       NaN        NaN
# 18         Columbus, New Jersey - 8022.       NaN        NaN
# 35          Tacoma, Washington - 98401.       NaN        NaN

# %%
empty_coord_df.reset_index(inplace=True)

# %%
empty_coord_df.drop('index', axis = 1, inplace=True)
# Out:
# C:\Users\Digant\AppData\Local\Temp\ipykernel_3140\3422125259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_coord_df.drop('index', axis = 1, inplace=True)

# %%
# Creating a pgeocode object
nomi = pgeocode.Nominatim('us')

# %%
# Getting all coordinates

mt_zips = empty_coord_df['zipcode'].values
mt_lat_cc = []
mt_long_cc = []

for j in range(empty_coord_df.shape[0]):
    zip_j = str(mt_zips[j])
    query_j = nomi.query_postal_code(zip_j)
    lat_j = query_j['latitude']
    long_j = query_j['longitude']
    mt_lat_cc.append(lat_j)
    mt_long_cc.append(long_j)

# %%
# Adding coordinates to dataframe

empty_coord_df['latitude'] = mt_lat_cc
empty_coord_df['longitude'] = mt_long_cc
# Out:
# C:\Users\Digant\AppData\Local\Temp\ipykernel_3140\932707043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_coord_df['latitude'] = mt_lat_cc
# C:\Users\Digant\AppData\Local\Temp\ipykernel_3140\932707043.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_coord_df['longitude'] = mt_long_cc

# %%
empty_coord_df.head()
# Out:
#         credit_card              city state  zipcode  credit_card_limit  \
# 0  7482288151831611        Birmingham    NJ     8011               4000
# 1  8536914250563809  Colorado Springs    CO    80509              14000
# 2  2216132730528773     San Francisco    CA    94101              18000
# 3  9548629685194612          Columbus    NJ     8022               7000
# 4  2925559987432581            Tacoma    WA    98401              10000
#
#                                Address  latitude  longitude
# 0       Birmingham, New Jersey - 8011.       NaN        NaN
# 1  Colorado Springs, Colorado - 80509.       NaN        NaN
# 2   San Francisco, California - 94101.       NaN        NaN
# 3         Columbus, New Jersey - 8022.       NaN        NaN
# 4          Tacoma, Washington - 98401.   47.2537  -122.4443

# %%
empty_coord_df['latitude'].isna().sum()
# Out:
# 48

# %%
# Creating a copy of the empty_coord_df to be on the safer side

mt_df_2 = empty_coord_df

# %%
# Since we have a copy of empty_coord_df as mt_df_2, we can drop rows with empty coords from empty_coord_df
empty_coord_df = empty_coord_df[empty_coord_df['latitude'].isna() == False]

# %%
empty_coord_df.reset_index(inplace=True)
empty_coord_df.drop('index', axis=1, inplace=True)
# Out:
# C:\Users\Digant\AppData\Local\Temp\ipykernel_3140\4158875309.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_coord_df.drop('index', axis=1, inplace=True)

# %%
empty_coord_df.head()
# Out:
#         credit_card        city state  zipcode  credit_card_limit  \
# 0  2925559987432581      Tacoma    WA    98401              10000
# 1  8534199181434464  Des Moines    IA    50301              20000
# 2  3801374660832282  Fort Worth    TX    76101              20000
# 3  3253141560871065  Cincinnati    OH    45201              30000
# 4  7011626867998686  Cincinnati    OH    45201               7000
#
#                        Address  latitude  longitude
# 0  Tacoma, Washington - 98401.   47.2537  -122.4443
# 1    Des Moines, Iowa - 50301.   41.6727   -93.5722
# 2   Fort Worth, Texas - 76101.   32.7714   -97.2915
# 3    Cincinnati, Ohio - 45201.   39.1668   -84.5382
# 4    Cincinnati, Ohio - 45201.   39.1668   -84.5382

# %%
# This dataframe will have all credit cards for which we had coordinates from the first attempt

old_coord_df = cc_[cc_['latitude'].isna()==False]

# %%
# Creating a new dataframe by merging old_coord_df and empty_coord_df
new_cc = pd.concat([old_coord_df,empty_coord_df])

# %%
# Creating lists of latitudes and longitudes of registration places of credit cards used in transactions

new_cc_list = new_cc['credit_card'].values

new_cc_lat = new_cc['latitude'].values
new_cc_lon = new_cc['longitude'].values

added_lat = []
added_lon = []
trans_cc_list = trans_['credit_card'].values

for j in range(trans_.shape[0]):
    #for every row in trans_
    # We take the credit card number
    trans_cc_j = trans_cc_list[j]
    # Then we check if the credit card number is in new_cc_list
    if trans_cc_j in new_cc_list:
        # We will now match the latitudes and longitudes
        for k in range(new_cc.shape[0]):
            if trans_cc_j == new_cc_list[k]:
                lat_jk = new_cc_lat[k]
                lon_jk = new_cc_lon[k]
                added_lat.append(lat_jk)
                added_lon.append(lon_jk)
        # If the credit card number is not in list, we will append np.NaN. These rows will later be deleted
    else:
        added_lat.append(np.NaN)
        added_lon.append(np.NaN)

# %%
# Adding the information to the trans_ dataframe
trans_['credit_card_lat'] = added_lat
trans_['credit_card_lon'] = added_lon

# %%
trans_[trans_['credit_card_lat'].isna()]
# Out:
#              credit_card                 date  transaction_dollar_amount  \
# 1187    1087468642191606  2015-08-04 15:56:40                      83.40
# 1188    1087468642191606  2015-09-03 19:04:22                      53.93
# 1189    1087468642191606  2015-08-15 23:32:06                      27.09
# 1190    1087468642191606  2015-09-10 22:48:11                     170.83
# 1191    1087468642191606  2015-08-07 19:14:08                      75.21
# ...                  ...                  ...                        ...
# 290911  9836548369808504  2015-09-21 01:51:11                      81.76
# 290912  9836548369808504  2015-09-30 18:48:32                      52.15
# 290913  9836548369808504  2015-09-07 16:37:57                     109.44
# 290914  9836548369808504  2015-10-15 17:31:42                      70.08
# 290915  9836548369808504  2015-08-26 19:10:40                      83.06
#
#               Long        Lat  credit_limit  perc_of_credit_limit  \
# 1187   -121.792036  47.485052          3000              2.780000
# 1188   -121.857773  47.373674          3000              1.797667
# 1189   -121.874610  47.444409          3000              0.903000
# 1190   -121.812252  47.511548          3000              5.694333
# 1191   -121.832278  47.434281          3000              2.507000
# ...            ...        ...           ...                   ...
# 290911 -121.827220  47.421394         20000              0.408800
# 290912 -121.852459  47.495084         20000              0.260750
# 290913 -121.852677  47.407030         20000              0.547200
# 290914 -121.839381  47.424876         20000              0.350400
# 290915 -121.848390  47.444022         20000              0.415300
#
#         credit_card_lat  credit_card_lon
# 1187                NaN              NaN
# 1188                NaN              NaN
# 1189                NaN              NaN
# 1190                NaN              NaN
# 1191                NaN              NaN
# ...                 ...              ...
# 290911              NaN              NaN
# 290912              NaN              NaN
# 290913              NaN              NaN
# 290914              NaN              NaN
# 290915              NaN              NaN
#
# [14588 rows x 9 columns]

# %%
# Creating a dataframe that does not have NaN values for coordinates of registration places
dist_imp_trans_ = trans_[trans_['credit_card_lat'].isna() == False]

# %% [markdown]
# ## 4. Calculating the distance between place of transaction and place of registration

# %%
#This is the credit card registration coordinate
test_cc_coord = (dist_imp_trans_['credit_card_lat'][0], dist_imp_trans_['credit_card_lon'][0])

#This is the transaction coordinate
test_trans_coord= (dist_imp_trans_['Lat'][0], dist_imp_trans_['Long'][0])

#This the distance between the two
test_distance = geopy.distance.geodesic(test_cc_coord, test_trans_coord).km

# %%
test_distance
# Out:
# 3.933043641442364

# %%
# Now we will repeat the process for all transactions

# Here we are just collecting all required values

dit_cc_lat = dist_imp_trans_['credit_card_lat'].values
dit_cc_lon = dist_imp_trans_['credit_card_lon'].values

dit_t_lat = dist_imp_trans_['Lat'].values
dit_t_lon = dist_imp_trans_['Long'].values

# %%
# Applying the geopy.distance.geodesic query

distances = []
for j in range(dist_imp_trans_.shape[0]):
    cc_coord_j = (dit_cc_lat[j], dit_cc_lon[j])
    trans_coord_j = (dit_t_lat[j], dit_t_lon[j])
    distance_j = geopy.distance.geodesic(cc_coord_j, trans_coord_j).km
    distances.append(distance_j)

# %%
# Adding the information gathered to the dataframe

dist_imp_trans_['Distance_from_registration_place'] = distances
# Out:
# C:\Users\Digant\AppData\Local\Temp\ipykernel_3140\3551358291.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dist_imp_trans_['Distance_from_registration_place'] = distances

# %%
dist_imp_trans_['Distance_from_registration_place'].describe()
# Out:
# count    280000.000000
# mean        173.652183
# std        1285.129625
# min           0.025687
# 25%           4.484742
# 50%           6.402246
# 75%           8.172051
# max       19743.725955
# Name: Distance_from_registration_place, dtype: float64

# %%
dist_imp_trans_.head()
# Out:
#         credit_card                 date  transaction_dollar_amount  \
# 0  1003715054175576  2015-09-11 00:32:40                      43.78
# 1  1003715054175576  2015-10-24 22:23:08                     103.15
# 2  1003715054175576  2015-10-26 18:19:36                      48.55
# 3  1003715054175576  2015-10-22 19:41:10                     136.18
# 4  1003715054175576  2015-10-26 20:08:22                      71.82
#
#         Long        Lat  credit_limit  perc_of_credit_limit  credit_card_lat  \
# 0 -80.174132  40.267370         20000               0.21890        40.246459
# 1 -80.194240  40.180114         20000               0.51575        40.246459
# 2 -80.211033  40.313004         20000               0.24275        40.246459
# 3 -80.174138  40.290895         20000               0.68090        40.246459
# 4 -80.238720  40.166719         20000               0.35910        40.246459
#
#    credit_card_lon  Distance_from_registration_place
# 0       -80.211447                          3.933044
# 1       -80.211447                          7.511141
# 2       -80.211447                          7.389253
# 3       -80.211447                          5.866592
# 4       -80.211447                          9.153604

# %% [markdown]
# ## 5. Normalising the data and building a model having a sigmoid layer at the end
#
# Here, we will first start with the date and time column to convert it into epoch timestamp. Then, we will use scikit to normalise the data.

# %%
dist_imp_trans_.dtypes
# Out:
# credit_card                           int64
# date                                 object
# transaction_dollar_amount           float64
# Long                                float64
# Lat                                 float64
# credit_limit                          int64
# perc_of_credit_limit                float64
# credit_card_lat                     float64
# credit_card_lon                     float64
# Distance_from_registration_place    float64
# dtype: object

# %%
dist_imp_trans_['date'] = pd.to_datetime(dist_imp_trans_['date'])
# Out:
# C:\Users\Digant\AppData\Local\Temp\ipykernel_3140\742923549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dist_imp_trans_['date'] = pd.to_datetime(dist_imp_trans_['date'])

# %%
dist_imp_trans_['date'] = dist_imp_trans_['date'].apply(lambda x: x.timestamp())
# Out:
# C:\Users\Digant\AppData\Local\Temp\ipykernel_3140\1047055328.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dist_imp_trans_['date'] = dist_imp_trans_['date'].apply(lambda x: x.timestamp())

# %%
pipeline = Pipeline([('normalizer', Normalizer()),
                     ('scaler', MinMaxScaler())])

# %%
X = np.array(dist_imp_trans_)
pipeline.fit(X)
X_transform = pipeline.transform(X)

# %% [markdown]
# ## 6. Fitting the model and making predictions
# First, we will split the data for training and testing. Then, we will create a tensorflow model, compile it, and fit it on the training data. Then, we will make predictions out of both, testing and training data.

# %%
X_train, X_test = train_test_split(X_transform, test_size=0.33, random_state=42)

# %%
BATCH_SIZE = 10000
EPOCHS = 200

# %%
autoencoder = tf.keras.Sequential([
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(64),
    tf.keras.layers.Dense(1, activation="sigmoid"),
])

autoencoder.compile(optimizer="adam",
                    loss="mse",
                    metrics=["acc"])
# Out:
# WARNING:tensorflow:From C:\Users\Digant\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Digant\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = autoencoder.fit(X_train,
                          X_train, 
                          shuffle=True, 
                          epochs=EPOCHS, 
                          batch_size=BATCH_SIZE,
                          validation_data=(X_test, X_test))
# Out:
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\Digant\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Digant\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 19/19 [==============================] - 3s 36ms/step - loss: 0.1428 - acc: 4.8614e-04 - val_loss: 0.1175 - val_acc: 2.0130e-04
# Epoch 2/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1181 - acc: 1.8284e-04 - val_loss: 0.1181 - val_acc: 2.0130e-04
# Epoch 3/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1171 - acc: 1.8284e-04 - val_loss: 0.1171 - val_acc: 2.0130e-04
# Epoch 4/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1168 - acc: 1.8284e-04 - val_loss: 0.1169 - val_acc: 2.0130e-04
# Epoch 5/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1166 - acc: 1.8284e-04 - val_loss: 0.1168 - val_acc: 2.0130e-04
# Epoch 6/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1166 - acc: 1.8284e-04 - val_loss: 0.1167 - val_acc: 2.0130e-04
# Epoch 7/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1165 - acc: 1.8284e-04 - val_loss: 0.1167 - val_acc: 2.0130e-04
# Epoch 8/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1165 - acc: 1.8284e-04 - val_loss: 0.1167 - val_acc: 2.0130e-04
# Epoch 9/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1165 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0130e-04
# Epoch 10/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0130e-04
# Epoch 11/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0130e-04
# Epoch 12/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0130e-04
# Epoch 13/200
# 19/19 [==============================] - 0s 17ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0130e-04
# Epoch 14/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0130e-04
# Epoch 15/200
# 19/19 [==============================] - 0s 17ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0130e-04
# Epoch 16/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0130e-04
# Epoch 17/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0130e-04
# Epoch 18/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0130e-04
# Epoch 19/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0130e-04
# Epoch 20/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0130e-04
# Epoch 21/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0238e-04
# Epoch 22/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0238e-04
# Epoch 23/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1164 - acc: 1.8284e-04 - val_loss: 0.1166 - val_acc: 2.0238e-04
# Epoch 24/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 25/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 26/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 27/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 28/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 29/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 30/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 31/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 32/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 33/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 34/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 35/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 36/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 37/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0346e-04
# Epoch 38/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1163 - acc: 1.8284e-04 - val_loss: 0.1165 - val_acc: 2.0455e-04
# Epoch 39/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.8337e-04 - val_loss: 0.1165 - val_acc: 2.0563e-04
# Epoch 40/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1163 - acc: 1.8550e-04 - val_loss: 0.1165 - val_acc: 2.0671e-04
# Epoch 41/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.8603e-04 - val_loss: 0.1165 - val_acc: 2.0779e-04
# Epoch 42/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.8870e-04 - val_loss: 0.1165 - val_acc: 2.1104e-04
# Epoch 43/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1163 - acc: 1.9083e-04 - val_loss: 0.1165 - val_acc: 2.1212e-04
# Epoch 44/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1163 - acc: 1.9296e-04 - val_loss: 0.1165 - val_acc: 2.1429e-04
# Epoch 45/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.9296e-04 - val_loss: 0.1165 - val_acc: 2.1537e-04
# Epoch 46/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.9296e-04 - val_loss: 0.1165 - val_acc: 2.1645e-04
# Epoch 47/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.9403e-04 - val_loss: 0.1165 - val_acc: 2.1861e-04
# Epoch 48/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1163 - acc: 1.9403e-04 - val_loss: 0.1165 - val_acc: 2.1970e-04
# Epoch 49/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1163 - acc: 1.9403e-04 - val_loss: 0.1165 - val_acc: 2.1970e-04
# Epoch 50/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1163 - acc: 1.9456e-04 - val_loss: 0.1165 - val_acc: 2.1970e-04
# Epoch 51/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1163 - acc: 1.9456e-04 - val_loss: 0.1165 - val_acc: 2.1970e-04
# Epoch 52/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1163 - acc: 1.9456e-04 - val_loss: 0.1165 - val_acc: 2.1970e-04
# Epoch 53/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.9456e-04 - val_loss: 0.1165 - val_acc: 2.1861e-04
# Epoch 54/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.9456e-04 - val_loss: 0.1165 - val_acc: 2.1861e-04
# Epoch 55/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.9456e-04 - val_loss: 0.1165 - val_acc: 2.1861e-04
# Epoch 56/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.9456e-04 - val_loss: 0.1165 - val_acc: 2.1861e-04
# Epoch 57/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1163 - acc: 1.9456e-04 - val_loss: 0.1165 - val_acc: 2.1861e-04
# Epoch 58/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1163 - acc: 1.9456e-04 - val_loss: 0.1165 - val_acc: 2.1861e-04
# Epoch 59/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1163 - acc: 1.9456e-04 - val_loss: 0.1165 - val_acc: 2.1861e-04
# Epoch 60/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.9403e-04 - val_loss: 0.1165 - val_acc: 2.1861e-04
# Epoch 61/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.9403e-04 - val_loss: 0.1165 - val_acc: 2.1861e-04
# Epoch 62/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1163 - acc: 1.9403e-04 - val_loss: 0.1165 - val_acc: 2.1753e-04
# Epoch 63/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.9403e-04 - val_loss: 0.1165 - val_acc: 2.1753e-04
# Epoch 64/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.9403e-04 - val_loss: 0.1165 - val_acc: 2.1753e-04
# Epoch 65/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1163 - acc: 1.9403e-04 - val_loss: 0.1165 - val_acc: 2.1537e-04
# Epoch 66/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9403e-04 - val_loss: 0.1165 - val_acc: 2.1537e-04
# Epoch 67/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9350e-04 - val_loss: 0.1165 - val_acc: 2.1537e-04
# Epoch 68/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9296e-04 - val_loss: 0.1164 - val_acc: 2.1320e-04
# Epoch 69/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9296e-04 - val_loss: 0.1164 - val_acc: 2.1320e-04
# Epoch 70/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9296e-04 - val_loss: 0.1164 - val_acc: 2.1320e-04
# Epoch 71/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9296e-04 - val_loss: 0.1164 - val_acc: 2.1320e-04
# Epoch 72/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9296e-04 - val_loss: 0.1164 - val_acc: 2.1320e-04
# Epoch 73/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9243e-04 - val_loss: 0.1164 - val_acc: 2.1212e-04
# Epoch 74/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1162 - acc: 1.9190e-04 - val_loss: 0.1164 - val_acc: 2.1212e-04
# Epoch 75/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9136e-04 - val_loss: 0.1164 - val_acc: 2.1104e-04
# Epoch 76/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1162 - acc: 1.9136e-04 - val_loss: 0.1164 - val_acc: 2.1104e-04
# Epoch 77/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9083e-04 - val_loss: 0.1164 - val_acc: 2.0996e-04
# Epoch 78/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9083e-04 - val_loss: 0.1164 - val_acc: 2.0996e-04
# Epoch 79/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0996e-04
# Epoch 80/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0996e-04
# Epoch 81/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 82/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 83/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 84/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 85/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 86/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 87/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 88/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 89/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 90/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 91/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 92/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 93/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 94/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 95/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 96/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 97/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 98/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 99/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 100/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 101/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 102/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 103/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 104/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 105/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 106/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 107/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 108/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 109/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 110/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.9030e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 111/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 112/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 113/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 114/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 115/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 116/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 117/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 118/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 119/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 120/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 121/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 122/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 123/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 124/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 125/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 126/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 127/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 128/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 129/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 130/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 131/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 132/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 133/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 134/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 135/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 136/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 137/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 138/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 139/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 140/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 141/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 142/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 143/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 144/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 145/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 146/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 147/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 148/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 149/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 150/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 151/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 152/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 153/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 154/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 155/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 156/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 157/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 158/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 159/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 160/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 161/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 162/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 163/200
# 19/19 [==============================] - 0s 13ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 164/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 165/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 166/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 167/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 168/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 169/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 170/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 171/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 172/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 173/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 174/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 175/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 176/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 177/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 178/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 179/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 180/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 181/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 182/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 183/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 184/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 185/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 186/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 187/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 188/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 189/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 190/200
# 19/19 [==============================] - 0s 17ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 191/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 192/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 193/200
# 19/19 [==============================] - 0s 16ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 194/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 195/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 196/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 197/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 198/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 199/200
# 19/19 [==============================] - 0s 15ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04
# Epoch 200/200
# 19/19 [==============================] - 0s 14ms/step - loss: 0.1162 - acc: 1.8977e-04 - val_loss: 0.1164 - val_acc: 2.0887e-04

# %%
# Making predictions on test data
reconstructions = autoencoder.predict(X_test)
# Out:
# 2888/2888 [==============================] - 7s 2ms/step

# %%
# Making a dataframe out of predictions
fraud_or_no = pd.DataFrame(reconstructions, columns=['Prediction'])

# %%
fraud_or_no.reset_index(inplace=True)
fraud_or_no["index"] = fraud_or_no["index"] + 1

# %%
# Since we had a sigmoid layer at the end, the outliers or anomalies will have a value of over 0.5
nl_2 = []

for j in range(reconstructions.shape[0]):
    value = float(reconstructions[j])
    if value >= 0.5:
        nl_2.append(1)
    else:
        nl_2.append(0)

# %%
# Enumerating the anomalies

fraud_or_no['Approx'] = nl_2
fraud_or_no.groupby(['Approx']).count()
# Out:
#         index  Prediction
# Approx
# 0       92382       92382
# 1          18          18

# %%
# Making predictions on training data

recons_2 = autoencoder.predict(X_train)
# Out:
# 5863/5863 [==============================] - 13s 2ms/step

# %%
# Making a dataframe out of prediction
fon_2 = pd.DataFrame(recons_2, columns=['Prediction'])

fon_2.reset_index(inplace=True)

fon_2['index'] = fon_2['index'] + 1

# %%
# Since we had a sigmoid layer at the end, the outliers or anomalies will have a value of over 0.5

new_list = []

for j in range(recons_2.shape[0]):
    value = float(recons_2[j])
    if value >= 0.5:
        new_list.append(1)
    else:
        new_list.append(0)

# %%
# Enumerating the anomalies

fon_2['Approx'] = new_list

fon_2.groupby(['Approx']).count()
# Out:
#          index  Prediction
# Approx
# 0       187572      187572
# 1           28          28
